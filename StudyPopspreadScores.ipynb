# %% [markdown]
# <a href="https://colab.research.google.com/github/bofeng2268/qm2/blob/main/StudyPopspreadScores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install geopandas
# !pip install plotly

# %%
import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import geopandas as gpd
import requests
import json

# %%
# Paths to the files with Raw GitHub URLs
csv_file_path = 'https://raw.githubusercontent.com/Maxbruel/QM2/main/notebooks/FinalPOPSPREADandSCOREDATASET.csv'
topojson_file_path = 'https://raw.githubusercontent.com/bofeng2268/qm2/main/Phenomena/Local%20Authority%20Disability/topo_lad.json'
local_authorities_file_path = 'https://raw.githubusercontent.com/bofeng2268/qm2/main/Phenomena/Local%20Authority%20Disability/download6923730533685635445.csv'

# %%
pd.read_csv(csv_file_path, delimiter=';')
# Out:
#            Local Authority  Population Spread Score (/100)  \
# 0     Barking and Dagenham                            2.50
# 1                   Barnet                            4.30
# 2                   Bexley                            3.00
# 3                    Brent                            3.42
# 4                  Bromley                            4.00
# 5                   Camden                            2.80
# 6                  Croydon                            4.60
# 7                   Ealing                            3.80
# 8                  Enfield                            3.70
# 9                Greenwich                            3.50
# 10                 Hackney                            3.50
# 11  Hammersmith and Fulham                            2.00
# 12                Haringey                            3.01
# 13                  Harrow                            2.60
# 14                Havering                            3.50
# ...

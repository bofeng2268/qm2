# %% [markdown]
# <a href="https://colab.research.google.com/github/bofeng2268/qm2/blob/main/MaxAnalysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install geopandas
# !pip install plotly
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.23.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import geopandas as gpd
import requests
import json

# %%
# Paths to the files with Raw GitHub URLs
topojson_file_path = 'https://raw.githubusercontent.com/bofeng2268/qm2/main/Phenomena/Local%20Authority%20Disability/topo_lad.json'
local_authorities_file_path = 'https://raw.githubusercontent.com/Maxbruel/QM2/main/notebooks/Local%20Authorities%20London.csv'
csv_file_path = 'https://raw.githubusercontent.com/bofeng2268/qm2/main/Recent%20Acces%20Stations%20and%20Disabled%20People%202.csv'
# Load the CSV files
stations_disabled_people = pd.read_csv(csv_file_path)
local_authorities = pd.read_csv(local_authorities_file_path, delimiter=';')
# Load the TopoJSON file from the URL
response = requests.get(topojson_file_path)
topojson_data = response.json()
gdf = gpd.read_file(json.dumps(topojson_data), layer='lad')

# %%
local_authorities
# Out:
#                       Feature Identifier,Feature Name
# 0   http://opendatacommunities.org/id/geography/ad...
# 1   http://opendatacommunities.org/id/geography/ad...
# 2   http://opendatacommunities.org/id/geography/ad...
# 3   http://opendatacommunities.org/id/geography/ad...
# 4   http://opendatacommunities.org/id/geography/ad...
# 5   http://opendatacommunities.org/id/geography/ad...
# 6   http://opendatacommunities.org/id/geography/ad...
# 7   http://opendatacommunities.org/id/geography/ad...
# 8   http://opendatacommunities.org/id/geography/ad...
# 9   http://opendatacommunities.org/id/geography/ad...
# 10  http://opendatacommunities.org/id/geography/ad...
# 11  http://opendatacommunities.org/id/geography/ad...
# 12  http://opendatacommunities.org/id/geography/ad...
# 13  http://opendatacommunities.org/id/geography/ad...
# 14  http://opendatacommunities.org/id/geography/ad...
# 15  http://opendatacommunities.org/id/geography/ad...
# 16  http://opendatacommunities.org/id/geography/ad...
# 17  http://opendatacommunities.org/id/geography/ad...
# 18  http://opendatacommunities.org/id/geography/ad...
# 19  http://opendatacommunities.org/id/geography/ad...
# 20  http://opendatacommunities.org/id/geography/ad...
# 21  http://opendatacommunities.org/id/geography/ad...
# 22  http://opendatacommunities.org/id/geography/ad...
# 23  http://opendatacommunities.org/id/geography/ad...
# 24  http://opendatacommunities.org/id/geography/ad...
# 25  http://opendatacommunities.org/id/geography/ad...
# 26  http://opendatacommunities.org/id/geography/ad...
# 27  http://opendatacommunities.org/id/geography/ad...
# 28  http://opendatacommunities.org/id/geography/ad...
# 29  http://opendatacommunities.org/id/geography/ad...
# 30  http://opendatacommunities.org/id/geography/ad...
# 31  http://opendatacommunities.org/id/geography/ad...

# %%
print(local_authorities.columns)
print(stations_disabled_people.columns)
# Out:
# Index(['Feature Identifier,Feature Name'], dtype='object')
# Index(['Local Authority;Normalized accesibility score (/100);Share of transport reliant (/100)'], dtype='object')

# %%
merged_data = pd.merge(local_authorities, stations_disabled_people, left_on='Feature Name', right_on='Local Authority')

# Merge the GeoDataFrame with the merged data
final_merged_data = gdf.merge(merged_data, left_on='LAD13NM', right_on='Feature Name')

final_merged_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-6351a268fa30> in <cell line: 1>()
# ----> 1 merged_data = pd.merge(local_authorities, stations_disabled_people, left_on='Feature Name', right_on='Local Authority')
#       2
#       3 # Merge the GeoDataFrame with the merged data
#       4 final_merged_data = gdf.merge(merged_data, left_on='LAD13NM', right_on='Feature Name')
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1160                         rk = cast(Hashable, rk)
#    1161                         if rk is not None:
# -> 1162                             right_keys.append(right._get_label_or_level_values(rk))
#    1163                         else:
#    1164                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'Local Authority'

# %%
merged_data
# Out:
# Empty DataFrame
# Columns: [Feature Identifier,Feature Name, Local Authority;Normalized accesibility score (/100);Share of transport reliant (/100)]
# Index: []
